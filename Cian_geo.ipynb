# %% [markdown]
# # Загрузка данных

# %% [markdown]
# Добавим координаты домов, метро. Расстояния до метро и центра города.

# %%
import pandas as pd
import numpy as np
from geopy.geocoders import Yandex
from geopy.extra.rate_limiter import RateLimiter
from geopy.geocoders import Nominatim
from time import sleep
from geopy import distance

import pickle

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('data\cian_clean.csv')
df.head()
# Out:
#                         Название  \
# 0     5-комн. квартира, 140,6 м²
# 1       5-комн. квартира, 200 м²
# 2  4-комн. апартаменты, 207,9 м²
# 3  4-комн. апартаменты, 204,6 м²
# 4     5-комн. квартира, 264,6 м²
#
#                                                Адрес        Метро  \
# 0      Москва, ЦАО, р-н Тверской, ул. Петровка, 20/1      Трубная
# 1      Москва, ЦАО, р-н Тверской, Тверская ул., 12С7   Пушкинская
# 2      Москва, ЦАО, р-н Тверской, ул. Охотный Ряд, 2  Охотный ряд
# 3      Москва, ЦАО, р-н Тверской, ул. Охотный Ряд, 2  Охотный ряд
# 4  Москва, ЦАО, р-н Тверской, ул. Большая Дмитров...  Театральная
#
#    Время до метро         Цена  Цена за квадрат  Общая площадь  Жилая площадь  \
# 0             5.0   82000000.0         583215.0          140.6         81.600
# 1             3.0   75000000.0         375000.0          200.0        120.000
# 2             2.0  454889566.0        2188021.0          207.9        122.661
# 3             2.0  508714883.0        2486388.0          204.6        120.714
# 4             5.0  450000000.0        1700680.0          264.6        156.114
#
#    Площадь кухни  Этаж  ...  Мусоропровод Количество лифтов    Тип дома  \
# 0         15.600     5  ...           Нет                 1   Кирпичный
# 1         20.000     6  ...            Да                 1   Кирпичный
# 2         35.343     5  ...            Да                 1  Монолитный
# 3         34.782     6  ...            Да                 1  Монолитный
# 4         30.000     7  ...            Да                 1  Монолитный
#
#    Тип перекрытий  Парковка       Отопление Балкон/лоджия     Отделка  \
# 0  Нет информации  Наземная     Центральное             1  Неизвестно
# 1  Нет информации  Наземная     Центральное             1  Неизвестно
# 2  Нет информации  Наземная  Нет информации             1  Неизвестно
# 3  Нет информации  Наземная  Нет информации             1  Неизвестно
# 4  Железобетонные  Наземная     Центральное             1  Неизвестно
#
#   Этажность здания Кол-во комнат
# 0                5             5
# 1                6             5
# 2               15             4
# 3               15             4
# 4                7             5
#
# [5 rows x 26 columns]

# %% [markdown]
# # Поиск и добавление координат

# %%
geolocator = Yandex(api_key="df6b0204-4bd5-42a4-af8a-5c128c3c9834")

# %%
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=0.5)

# %% [markdown]
# ## Поиск координат метро.

# %%
df['Город и метро'] = 'Москва, метро ' + df['Метро']
df['Город и метро'].head()
# Out:
# 0        Москва, метро Трубная
# 1     Москва, метро Пушкинская
# 2    Москва, метро Охотный ряд
# 3    Москва, метро Охотный ряд
# 4    Москва, метро Театральная
# Name: Город и метро, dtype: object

# %%
df['Город и метро'].nunique()
# Out:
# 295

# %%
metro = dict()  # Поиск локаций метро.
for met in df['Город и метро'].unique():
    metro[met] = geocode(met)

# %%
metro
# Out:
# {'Москва, метро Трубная': Location(метро Трубная, Люблинско-Дмитровская линия, Москва, Россия, (55.767833, 37.622028, 0.0)),
#  'Москва, метро Пушкинская': Location(метро Пушкинская, Таганско-Краснопресненская линия, Москва, Россия, (55.765752, 37.6039, 0.0)),
#  'Москва, метро Охотный ряд': Location(метро Охотный Ряд, Сокольническая линия, Москва, Россия, (55.756969, 37.615524, 0.0)),
#  'Москва, метро Театральная': Location(метро Театральная, Замоскворецкая линия, Москва, Россия, (55.757967, 37.619001, 0.0)),
#  'Москва, метро Чеховская': Location(метро Чеховская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.765843, 37.608167, 0.0)),
#  'Москва, метро Тверская': Location(метро Тверская, Замоскворецкая линия, Москва, Россия, (55.76446, 37.605948, 0.0)),
#  'Москва, метро Улица 1905 года': Location(метро Улица 1905 года, Таганско-Краснопресненская линия, Москва, Россия, (55.764759, 37.561401, 0.0)),
#  'Москва, метро Лубянка': Location(метро Лубянка, Сокольническая линия, Москва, Россия, (55.759618, 37.626762, 0.0)),
#  'Москва, метро Третьяковская': Location(метро Третьяковская, Калужско-Рижская линия, Москва, Россия, (55.741267, 37.62563, 0.0)),
#  'Москва, метро Арбатская': Location(метро Арбатская, Филёвская линия, Москва, Россия, (55.75207, 37.601367, 0.0)),
#  'Москва, метро Кузнецкий мост': Location(метро Кузнецкий Мост, Таганско-Краснопресненская линия, Москва, Россия, (55.761512, 37.624516, 0.0)),
#  'Москва, метро Боровицкая': Location(метро Боровицкая, Серпуховско-Тимирязевская линия, Москва, Россия, (55.750575, 37.608652, 0.0)),
#  'Москва, метро Александровский сад': Location(метро Александровский сад, Филёвская линия, Москва, Россия, (55.752354, 37.60947, 0.0)),
#  'Москва, метро Китай-город': Location(метро Китай-город, Калужско-Рижская линия, Москва, Россия, (55.757009, 37.631299, 0.0)),
#  'Москва, метро Цветной бульвар': Location(метро Цветной бульвар, Серпуховско-Тимирязевская линия, Москва, Россия, (55.771758, 37.620734, 0.0)),
#  'Москва, метро Библиотека им. Ленина': Location(метро Библиотека имени Ленина, Сокольническая линия, Москва, Россия, (55.75132, 37.610116, 0.0)),
#  'Москва, метро Сухаревская': Location(метро Сухаревская, Калужско-Рижская линия, Москва, Россия, (55.772497, 37.632305, 0.0)),
#  'Москва, метро Кропоткинская': Location(метро Кропоткинская, Сокольническая линия, Москва, Россия, (55.745073, 37.603487, 0.0)),
#  'Москва, метро Чистые пруды': Location(метро Чистые пруды, Сокольническая линия, Москва, Россия, (55.764794, 37.638692, 0.0)),
#  'Москва, метро Каширская': Location(метро Каширская, Большая кольцевая линия, Москва, Россия, (55.654462, 37.647639, 0.0)),
#  'Москва, метро Коломенская': Location(метро Коломенская, Замоскворецкая линия, Москва, Россия, (55.678412, 37.663845, 0.0)),
#  'Москва, метро Новокузнецкая': Location(метро Новокузнецкая, Замоскворецкая линия, Москва, Россия, (55.742372, 37.629241, 0.0)),
#  'Москва, метро Царицыно': Location(метро Царицыно, Замоскворецкая линия, Москва, Россия, (55.621607, 37.669154, 0.0)),
#  'Москва, метро Домодедовская': Location(метро Домодедовская, Замоскворецкая линия, Москва, Россия, (55.610845, 37.718669, 0.0)),
#  'Москва, метро Кантемировская': Location(метро Кантемировская, Замоскворецкая линия, Москва, Россия, (55.636107, 37.656218, 0.0)),
#  'Москва, метро Воробьёвы горы': Location(метро Воробьёвы горы, Сокольническая линия, Москва, Россия, (55.710433, 37.559335, 0.0)),
#  'Москва, метро Зябликово': Location(метро Зябликово, Люблинско-Дмитровская линия, Москва, Россия, (55.612334, 37.745187, 0.0)),
#  'Москва, метро Варшавская': Location(метро Варшавская, Большая кольцевая линия, Москва, Россия, (55.653309, 37.619495, 0.0)),
#  'Москва, метро Ленинский проспект': Location(метро Ленинский проспект, Калужско-Рижская линия, Москва, Россия, (55.707152, 37.585404, 0.0)),
#  'Москва, метро Смоленская': Location(метро Смоленская, Филёвская линия, Москва, Россия, (55.748762, 37.58217, 0.0)),
#  'Москва, метро Университет': Location(метро Университет, Сокольническая линия, Москва, Россия, (55.692612, 37.533526, 0.0)),
#  'Москва, метро Орехово': Location(метро Орехово, Замоскворецкая линия, Москва, Россия, (55.612934, 37.695268, 0.0)),
#  'Москва, метро Парк Культуры': Location(метро Парк культуры, Кольцевая линия, Москва, Россия, (55.735307, 37.592869, 0.0)),
#  'Москва, метро Площадь Гагарина': Location(станция Площадь Гагарина, Московское центральное кольцо, Москва, Россия, (55.706827, 37.586625, 0.0)),
#  'Москва, метро Спортивная': Location(метро Спортивная, Сокольническая линия, Москва, Россия, (55.723328, 37.564123, 0.0)),
#  'Москва, метро Академическая': Location(метро Академическая, Калужско-Рижская линия, Москва, Россия, (55.68766, 37.573348, 0.0)),
#  'Москва, метро Фрунзенская': Location(метро Фрунзенская, Сокольническая линия, Москва, Россия, (55.727328, 37.580481, 0.0)),
#  'Москва, метро Киевская': Location(метро Киевская, Филёвская линия, Москва, Россия, (55.743588, 37.565587, 0.0)),
#  'Москва, метро Красные ворота': Location(метро Красные Ворота, Сокольническая линия, Москва, Россия, (55.768664, 37.649229, 0.0)),
#  'Москва, метро Сретенский бульвар': Location(метро Сретенский бульвар, Люблинско-Дмитровская линия, Москва, Россия, (55.765564, 37.638404, 0.0)),
#  'Москва, метро Баррикадная': Location(метро Баррикадная, Таганско-Краснопресненская линия, Москва, Россия, (55.760818, 37.58128, 0.0)),
#  'Москва, метро Таганская': Location(метро Таганская, Таганско-Краснопресненская линия, Москва, Россия, (55.739549, 37.652957, 0.0)),
#  'Москва, метро Марксистская': Location(метро Марксистская, Калининская линия, Москва, Россия, (55.741303, 37.655957, 0.0)),
#  'Москва, метро Тургеневская': Location(метро Тургеневская, Калужско-Рижская линия, Москва, Россия, (55.765235, 37.636751, 0.0)),
#  'Москва, метро Курская': Location(метро Курская, Арбатско-Покровская линия, Москва, Россия, (55.758468, 37.65876, 0.0)),
#  'Москва, метро Проспект Мира': Location(метро Проспект Мира, Калужско-Рижская линия, Москва, Россия, (55.781747, 37.633032, 0.0)),
#  'Москва, метро Ясенево': Location(метро Ясенево, Калужско-Рижская линия, Москва, Россия, (55.606207, 37.533454, 0.0)),
#  'Москва, метро Новоясеневская': Location(метро Новоясеневская, Калужско-Рижская линия, Москва, Россия, (55.601717, 37.553837, 0.0)),
#  'Москва, метро Пролетарская': Location(метро Пролетарская, Таганско-Краснопресненская линия, Москва, Россия, (55.731673, 37.666162, 0.0)),
#  'Москва, метро Крестьянская застава': Location(метро Крестьянская Застава, Люблинско-Дмитровская линия, Москва, Россия, (55.732651, 37.66503, 0.0)),
#  'Москва, метро Полянка': Location(метро Полянка, Серпуховско-Тимирязевская линия, Москва, Россия, (55.736904, 37.618695, 0.0)),
#  'Москва, метро Пражская': Location(метро Пражская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.612599, 37.604565, 0.0)),
#  'Москва, метро Филёвский парк': Location(метро Филёвский парк, Филёвская линия, Москва, Россия, (55.739524, 37.483328, 0.0)),
#  'Москва, метро Студенческая': Location(метро Студенческая, Филёвская линия, Москва, Россия, (55.738809, 37.548402, 0.0)),
#  'Москва, метро Измайловская': Location(метро Измайловская, Арбатско-Покровская линия, Москва, Россия, (55.787761, 37.781506, 0.0)),
#  'Москва, метро Измайлово': Location(станция Измайлово, Московское центральное кольцо, Москва, Россия, (55.788722, 37.743058, 0.0)),
#  'Москва, метро Пионерская': Location(метро Пионерская, Филёвская линия, Москва, Россия, (55.735991, 37.467087, 0.0)),
#  'Москва, метро Кунцевская': Location(метро Кунцевская, Арбатско-Покровская линия, Москва, Россия, (55.730629, 37.44559, 0.0)),
#  'Москва, метро Парк Победы': Location(метро Парк Победы, Арбатско-Покровская линия, Москва, Россия, (55.736934, 37.516009, 0.0)),
#  'Москва, метро Площадь Ильича': Location(метро Площадь Ильича, Калининская линия, Москва, Россия, (55.747089, 37.681335, 0.0)),
#  'Москва, метро Багратионовская': Location(метро Багратионовская, Филёвская линия, Москва, Россия, (55.743801, 37.497863, 0.0)),
#  'Москва, метро Славянский бульвар': Location(метро Славянский бульвар, Арбатско-Покровская линия, Москва, Россия, (55.729579, 37.470581, 0.0)),
#  'Москва, метро Кутузовская': Location(метро Кутузовская, Филёвская линия, Москва, Россия, (55.74033, 37.5342, 0.0)),
#  'Москва, метро Выставочная': Location(метро Выставочная, Филёвская линия, Москва, Россия, (55.750175, 37.541431, 0.0)),
#  'Москва, метро Площадь Революции': Location(метро Площадь Революции, Арбатско-Покровская линия, Москва, Россия, (55.756807, 37.622729, 0.0)),
#  'Москва, метро Октябрьская': Location(метро Октябрьская, Кольцевая линия, Москва, Россия, (55.729219, 37.611185, 0.0)),
#  'Москва, метро Маяковская': Location(метро Маяковская, Замоскворецкая линия, Москва, Россия, (55.770178, 37.595501, 0.0)),
#  'Москва, метро Достоевская': Location(метро Достоевская, Люблинско-Дмитровская линия, Москва, Россия, (55.781499, 37.614707, 0.0)),
#  'Москва, метро Комсомольская': Location(метро Комсомольская, Кольцевая линия, Москва, Россия, (55.775707, 37.6547, 0.0)),
#  'Москва, метро Окружная': Location(метро Окружная, Люблинско-Дмитровская линия, Москва, Россия, (55.845542, 37.574229, 0.0)),
#  'Москва, метро Бауманская': Location(метро Бауманская, Арбатско-Покровская линия, Москва, Россия, (55.772411, 37.679044, 0.0)),
#  'Москва, метро Добрынинская': Location(метро Добрынинская, Кольцевая линия, Москва, Россия, (55.728996, 37.622747, 0.0)),
#  'Москва, метро Площадь трёх вокзалов': Location(Комсомольская площадь, Москва, Россия, (55.775327, 37.655643, 0.0)),
#  'Москва, метро Красносельская': Location(метро Красносельская, Сокольническая линия, Москва, Россия, (55.779818, 37.666225, 0.0)),
#  'Москва, метро Петровско-Разумовская': Location(метро Петровско-Разумовская, Люблинско-Дмитровская линия, Москва, Россия, (55.834451, 37.57422, 0.0)),
#  'Москва, метро Тимирязевская': Location(метро Тимирязевская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.8187, 37.57528, 0.0)),
#  'Москва, метро Соколиная гора': Location(станция Соколиная Гора, Московское центральное кольцо, Москва, Россия, (55.769919, 37.745385, 0.0)),
#  'Москва, метро Павелецкая': Location(метро Павелецкая, Кольцевая линия, Москва, Россия, (55.73182, 37.637003, 0.0)),
#  'Москва, метро Фонвизинская': Location(метро Фонвизинская, Люблинско-Дмитровская линия, Москва, Россия, (55.822893, 37.587353, 0.0)),
#  'Москва, метро Первомайская': Location(метро Первомайская, Арбатско-Покровская линия, Москва, Россия, (55.794614, 37.799427, 0.0)),
#  'Москва, метро Щёлковская': Location(метро Щёлковская, Арбатско-Покровская линия, Москва, Россия, (55.809717, 37.798592, 0.0)),
#  'Москва, метро Сокольники': Location(метро Сокольники, Большая кольцевая линия, Москва, Россия, (55.790109, 37.679376, 0.0)),
#  'Москва, метро Владыкино': Location(метро Владыкино, Серпуховско-Тимирязевская линия, Москва, Россия, (55.847983, 37.59038, 0.0)),
#  'Москва, метро Автозаводская': Location(метро Автозаводская, Замоскворецкая линия, Москва, Россия, (55.707299, 37.6577, 0.0)),
#  'Москва, метро Рижская': Location(метро Рижская, Большая кольцевая линия, Москва, Россия, (55.793865, 37.634515, 0.0)),
#  'Москва, метро Нагатинская': Location(метро Нагатинская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.683392, 37.622872, 0.0)),
#  'Москва, метро Шаболовская': Location(метро Шаболовская, Калужско-Рижская линия, Москва, Россия, (55.718821, 37.607933, 0.0)),
#  'Москва, метро Менделеевская': Location(метро Менделеевская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.781767, 37.59878, 0.0)),
#  'Москва, метро Новослободская': Location(метро Новослободская, Кольцевая линия, Москва, Россия, (55.779565, 37.601421, 0.0)),
#  'Москва, метро Дубровка': Location(метро Дубровка, Люблинско-Дмитровская линия, Москва, Россия, (55.71807, 37.67625, 0.0)),
#  'Москва, метро Белорусская': Location(метро Белорусская, Замоскворецкая линия, Москва, Россия, (55.777393, 37.582215, 0.0)),
#  'Москва, метро Битцевский парк': Location(метро Битцевский парк, Бутовская линия, Москва, Россия, (55.600323, 37.556235, 0.0)),
#  'Москва, метро Локомотив': Location(станция Локомотив, Московское центральное кольцо, Москва, Россия, (55.804056, 37.745969, 0.0)),
#  'Москва, метро Гражданская': Location(станция Гражданская, МЦД-2 Курско-Рижский диаметр, Россия, (55.805483, 37.553325, 0.0)),
#  'Москва, метро Шелепиха': Location(метро Шелепиха, Большая кольцевая линия, Москва, Россия, (55.757121, 37.524076, 0.0)),
#  'Москва, метро Дмитровская': Location(метро Дмитровская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.807602, 37.581262, 0.0)),
#  'Москва, метро Улица Академика Янгеля': Location(метро Улица Академика Янгеля, Серпуховско-Тимирязевская линия, Москва, Россия, (55.595293, 37.600873, 0.0)),
#  'Москва, метро Нагорная': Location(метро Нагорная, Серпуховско-Тимирязевская линия, Москва, Россия, (55.672691, 37.610592, 0.0)),
#  'Москва, метро Аннино': Location(метро Аннино, Серпуховско-Тимирязевская линия, Москва, Россия, (55.583205, 37.59674, 0.0)),
#  'Москва, метро Международная': Location(метро Международная, Филёвская линия, Москва, Россия, (55.748311, 37.534263, 0.0)),
#  'Москва, метро Савёловская': Location(метро Савёловская, Большая кольцевая линия, Москва, Россия, (55.792807, 37.586122, 0.0)),
#  'Москва, метро Черкизовская': Location(метро Черкизовская, Сокольническая линия, Москва, Россия, (55.803676, 37.744927, 0.0)),
#  'Москва, метро Печатники': Location(метро Печатники, Большая кольцевая линия, Москва, Россия, (55.694616, 37.727346, 0.0)),
#  'Москва, метро Волжская': Location(метро Волжская, Люблинско-Дмитровская линия, Москва, Россия, (55.690902, 37.753164, 0.0)),
#  'Москва, метро Давыдково': Location(метро Давыдково, Большая кольцевая линия, Москва, Россия, (55.71517, 37.45177, 0.0)),
#  'Москва, метро Депо': Location(Москва, Россия, (55.755819, 37.617644, 0.0)),
#  'Москва, метро Лесопарковая': Location(метро Лесопарковая, Бутовская линия, Москва, Россия, (55.582055, 37.577031, 0.0)),
#  'Москва, метро Планерная': Location(метро Планерная, Таганско-Краснопресненская линия, Москва, Россия, (55.860928, 37.436409, 0.0)),
#  'Москва, метро Электрозаводская': Location(метро Электрозаводская, Большая кольцевая линия, Москва, Россия, (55.780284, 37.70302, 0.0)),
#  'Москва, метро Кожуховская': Location(метро Кожуховская, Люблинско-Дмитровская линия, Москва, Россия, (55.706371, 37.685341, 0.0)),
#  'Москва, метро Чкаловская': Location(метро Чкаловская, Люблинско-Дмитровская линия, Москва, Россия, (55.755809, 37.658006, 0.0)),
#  'Москва, метро Серпуховская': Location(метро Серпуховская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.727293, 37.6251, 0.0)),
#  'Москва, метро Беломорская': Location(метро Беломорская, Замоскворецкая линия, Москва, Россия, (55.865374, 37.475692, 0.0)),
#  'Москва, метро Красный Строитель': Location(станция Красный Строитель, МЦД-2 Курско-Рижский диаметр, Россия, (55.589753, 37.615075, 0.0)),
#  'Москва, метро Сходненская': Location(метро Сходненская, Таганско-Краснопресненская линия, Москва, Россия, (55.85052, 37.439535, 0.0)),
#  'Москва, метро Москворечье': Location(станция Москворечье, МЦД-2 Курско-Рижский диаметр, Россия, (55.640396, 37.689087, 0.0)),
#  'Москва, метро Крымская': Location(станция Крымская, Московское центральное кольцо, Москва, Россия, (55.690004, 37.605122, 0.0)),
#  'Москва, метро Улица Скобелевская': Location(метро Улица Скобелевская, Бутовская линия, Москва, Россия, (55.548049, 37.554645, 0.0)),
#  'Москва, метро Деловой центр': Location(метро Деловой центр, Большая кольцевая линия, Москва, Россия, (55.749101, 37.540129, 0.0)),
#  'Москва, метро Лужники': Location(станция Лужники, Московское центральное кольцо, Москва, Россия, (55.720834, 37.560323, 0.0)),
#  'Москва, метро Выхино': Location(метро Выхино, Таганско-Краснопресненская линия, Москва, Россия, (55.715606, 37.81804, 0.0)),
#  'Москва, метро Люблино': Location(метро Люблино, Люблинско-Дмитровская линия, Москва, Россия, (55.675682, 37.761869, 0.0)),
#  'Москва, метро Улица Горчакова': Location(метро Улица Горчакова, Бутовская линия, Москва, Россия, (55.541937, 37.531514, 0.0)),
#  'Москва, метро Кузьминки': Location(метро Кузьминки, Таганско-Краснопресненская линия, Москва, Россия, (55.705463, 37.766154, 0.0)),
#  'Москва, метро Бульвар Адмирала Ушакова': Location(метро Бульвар Адмирала Ушакова, Бутовская линия, Москва, Россия, (55.545319, 37.542833, 0.0)),
#  'Москва, метро Тульская': Location(метро Тульская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.708841, 37.622621, 0.0)),
#  'Москва, метро Калитники': Location(станция Калитники, МЦД-2 Курско-Рижский диаметр, Россия, (55.734151, 37.701978, 0.0)),
#  'Москва, метро Юго-Восточная': Location(метро Юго-Восточная, Некрасовская линия, Москва, Россия, (55.705351, 37.817995, 0.0)),
#  'Москва, метро Улица Милашенкова': Location(монорельс Улица Милашенкова, Московская монорельсовая транспортная система, Москва, Россия, (55.821876, 37.591216, 0.0)),
#  'Москва, метро Марьина Роща': Location(метро Марьина Роща, Большая кольцевая линия, Москва, Россия, (55.796562, 37.615901, 0.0)),
#  'Москва, метро Бульвар Дмитрия Донского': Location(метро Бульвар Дмитрия Донского, Серпуховско-Тимирязевская линия, Москва, Россия, (55.569673, 37.577355, 0.0)),
#  'Москва, метро Севастопольская': Location(метро Севастопольская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.652085, 37.59833, 0.0)),
#  'Москва, метро Чертановская': Location(метро Чертановская, Серпуховско-Тимирязевская линия, Москва, Россия, (55.640609, 37.606325, 0.0)),
#  'Москва, метро Алексеевская': Location(метро Алексеевская, Калужско-Рижская линия, Москва, Россия, (55.807805, 37.638737, 0.0)),
#  'Москва, метро Нахимовский проспект': Location(метро Нахимовский проспект, Серпуховско-Тимирязевская линия, Москва, Россия, (55.662501, 37.605373, 0.0)),
#  'Москва, метро Текстильщики': Location(метро Текстильщики, Большая кольцевая линия, Москва, Россия, (55.707725, 37.728406, 0.0)),
#  'Москва, метро Фили': Location(метро Фили, Филёвская линия, Москва, Россия, (55.74597, 37.514958, 0.0)),
#  'Москва, метро Бутово': Location(станция Бутово, МЦД-2 Курско-Рижский диаметр, Россия, (55.541698, 37.57068, 0.0)),
#  'Москва, метро Битца': Location(станция Битца, МЦД-2 Курско-Рижский диаметр, Россия, (55.571179, 37.611473, 0.0)),
#  'Москва, метро Зюзино': Location(метро Зюзино, Большая кольцевая линия, Москва, Россия, (55.655717, 37.57369, 0.0)),
#  'Москва, метро Коньково': Location(метро Коньково, Калужско-Рижская линия, Москва, Россия, (55.63316, 37.518973, 0.0)),
#  'Москва, метро Тёплый Стан': Location(метро Тёплый Стан, Калужско-Рижская линия, Москва, Россия, (55.618939, 37.508346, 0.0)),
#  'Москва, метро Партизанская': Location(метро Партизанская, Арбатско-Покровская линия, Москва, Россия, (55.788464, 37.749984, 0.0)),
#  'Москва, метро Каховская': Location(метро Каховская, Большая кольцевая линия, Москва, Россия, (55.652822, 37.597612, 0.0)),
#  'Москва, метро Шипиловская': Location(метро Шипиловская, Люблинско-Дмитровская линия, Москва, Россия, (55.621165, 37.743696, 0.0)),
#  'Москва, метро Авиамоторная': Location(метро Авиамоторная, Калининская линия, Москва, Россия, (55.752055, 37.71733, 0.0)),
#  'Москва, метро Красногвардейская': Location(метро Красногвардейская, Замоскворецкая линия, Москва, Россия, (55.613692, 37.744046, 0.0)),
#  'Москва, метро Римская': Location(метро Римская, Люблинско-Дмитровская линия, Москва, Россия, (55.746233, 37.681245, 0.0)),
#  'Москва, метро Новогиреево': Location(метро Новогиреево, Калининская линия, Москва, Россия, (55.751665, 37.817169, 0.0)),
#  'Москва, метро Бутырская': Location(метро Бутырская, Люблинско-Дмитровская линия, Москва, Россия, (55.8134, 37.602481, 0.0)),
#  'Москва, метро Бунинская аллея': Location(метро Бунинская аллея, Бутовская линия, Москва, Россия, (55.537969, 37.515928, 0.0)),
#  'Москва, метро Волгоградский проспект': Location(метро Волгоградский проспект, Таганско-Краснопресненская линия, Москва, Россия, (55.724981, 37.687084, 0.0)),
#  'Москва, метро Отрадное': Location(метро Отрадное, Серпуховско-Тимирязевская линия, Москва, Россия, (55.863212, 37.604771, 0.0)),
#  'Москва, метро Ломоносовский проспект': Location(метро Ломоносовский проспект, Солнцевская линия, Москва, Россия, (55.70706, 37.516063, 0.0)),
#  'Москва, метро Ботанический сад': Location(метро Ботанический сад, Калужско-Рижская линия, Москва, Россия, (55.844895, 37.637946, 0.0)),
#  'Москва, метро Рязанский проспект': Location(метро Рязанский проспект, Таганско-Краснопресненская линия, Москва, Россия, (55.717097, 37.793364, 0.0)),
#  'Москва, метро Преображенская площадь': Location(метро Преображенская площадь, Сокольническая линия, Москва, Россия, (55.796172, 37.715022, 0.0)),
#  'Москва, метро Перово': Location(метро Перово, Калининская линия, Москва, Россия, (55.75132, 37.786887, 0.0)),
#  'Москва, метро Петровский Парк': Location(метро Петровский парк, Большая кольцевая линия, Москва, Россия, (55.79185, 37.557197, 0.0)),
#  'Москва, метро Крылатское': Location(метро Крылатское, Арбатско-Покровская линия, Москва, Россия, (55.756842, 37.408139, 0.0)),
#  'Москва, метро Угрешская': Location(станция Угрешская, Московское центральное кольцо, Москва, Россия, (55.717944, 37.695555, 0.0)),
#  'Москва, метро Бульвар Рокоссовского': Location(метро Бульвар Рокоссовского, Сокольническая линия, Москва, Россия, (55.814588, 37.734165, 0.0)),
#  'Москва, метро Поклонная': Location(станция Поклонная, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.732246, 37.521102, 0.0)),
#  'Москва, метро Молодёжная': Location(метро Молодёжная, Арбатско-Покровская линия, Москва, Россия, (55.740872, 37.416619, 0.0)),
#  'Москва, метро Семёновская': Location(метро Семёновская, Арбатско-Покровская линия, Москва, Россия, (55.7832, 37.719423, 0.0)),
#  'Москва, метро Тестовская': Location(станция Тестовская, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.750145, 37.530571, 0.0)),
#  'Москва, метро Раменки': Location(метро Раменки, Солнцевская линия, Москва, Россия, (55.697691, 37.498734, 0.0)),
#  'Москва, метро Покровское': Location(станция Покровское, МЦД-2 Курско-Рижский диаметр, Россия, (55.602973, 37.632071, 0.0)),
#  'Москва, метро Улица Старокачаловская': Location(метро Улица Старокачаловская, Бутовская линия, Москва, Россия, (55.568517, 37.576322, 0.0)),
#  'Москва, метро ЦСКА': Location(метро ЦСКА, Большая кольцевая линия, Москва, Россия, (55.786607, 37.53331, 0.0)),
#  'Москва, метро Динамо': Location(метро Динамо, Замоскворецкая линия, Москва, Россия, (55.789735, 37.558239, 0.0)),
#  'Москва, метро Южная': Location(метро Южная, Серпуховско-Тимирязевская линия, Москва, Россия, (55.622278, 37.608984, 0.0)),
#  'Москва, метро Балтийская': Location(станция Балтийская, Московское центральное кольцо, Москва, Россия, (55.825153, 37.494728, 0.0)),
#  'Москва, метро Тушинская': Location(метро Тушинская, Таганско-Краснопресненская линия, Москва, Россия, (55.826554, 37.436993, 0.0)),
#  'Москва, метро Тропарёво': Location(метро Тропарёво, Сокольническая линия, Москва, Россия, (55.645842, 37.472494, 0.0)),
#  'Москва, метро Беговая': Location(метро Беговая, Таганско-Краснопресненская линия, Москва, Россия, (55.773707, 37.546004, 0.0)),
#  'Москва, метро Стрешнево': Location(станция Стрешнево, Московское центральное кольцо, Москва, Россия, (55.813703, 37.486975, 0.0)),
#  'Москва, метро Речной вокзал': Location(метро Речной вокзал, Замоскворецкая линия, Москва, Россия, (55.854891, 37.476231, 0.0)),
#  'Москва, метро Реутов': Location(станция Реутов, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.751609, 37.855833, 0.0)),
#  'Москва, метро Бибирево': Location(метро Бибирево, Серпуховско-Тимирязевская линия, Москва, Россия, (55.883873, 37.60302, 0.0)),
#  'Москва, метро Алтуфьево': Location(метро Алтуфьево, Серпуховско-Тимирязевская линия, Москва, Россия, (55.898205, 37.587362, 0.0)),
#  'Москва, метро Новаторская': Location(метро Новаторская, Большая кольцевая линия, Москва, Россия, (55.669823, 37.52218, 0.0)),
#  'Москва, метро Борисово': Location(метро Борисово, Люблинско-Дмитровская линия, Москва, Россия, (55.633368, 37.743633, 0.0)),
#  'Москва, метро Окская': Location(метро Окская, Некрасовская линия, Москва, Россия, (55.718623, 37.781281, 0.0)),
#  'Москва, метро Войковская': Location(метро Войковская, Замоскворецкая линия, Москва, Россия, (55.819064, 37.498016, 0.0)),
#  'Москва, метро Коптево': Location(станция Коптево, Московское центральное кольцо, Москва, Россия, (55.840452, 37.521417, 0.0)),
#  'Москва, метро Верхние Лихоборы': Location(метро Верхние Лихоборы, Люблинско-Дмитровская линия, Москва, Россия, (55.856235, 37.561041, 0.0)),
#  'Москва, метро Красный Балтиец': Location(станция Красный Балтиец, МЦД-2 Курско-Рижский диаметр, Россия, (55.815483, 37.526627, 0.0)),
#  'Москва, метро Водный стадион': Location(метро Водный стадион, Замоскворецкая линия, Москва, Россия, (55.839891, 37.486796, 0.0)),
#  'Москва, метро Лианозово': Location(метро Лианозово, Люблинско-Дмитровская линия, Москва, Россия, (55.898614, 37.544854, 0.0)),
#  'Москва, метро Нагатинский Затон': Location(метро Нагатинский Затон, Большая кольцевая линия, Москва, Россия, (55.684427, 37.704592, 0.0)),
#  'Москва, метро Полежаевская': Location(метро Полежаевская, Таганско-Краснопресненская линия, Москва, Россия, (55.777449, 37.519315, 0.0)),
#  'Москва, метро Верхние котлы': Location(станция Верхние Котлы, Московское центральное кольцо, Москва, Россия, (55.69008, 37.618767, 0.0)),
#  'Москва, метро Юго-Западная': Location(метро Юго-Западная, Сокольническая линия, Москва, Россия, (55.663634, 37.483095, 0.0)),
#  'Москва, метро Краснопресненская': Location(метро Краснопресненская, Кольцевая линия, Москва, Россия, (55.760216, 37.57722, 0.0)),
#  'Москва, метро Дегунино': Location(станция Дегунино, МЦД-1 Белорусско-Савёловский диаметр, Россия, (55.865581, 37.573232, 0.0)),
#  'Москва, метро Хорошёвская': Location(станция Хорошёво, Московское центральное кольцо, Москва, Россия, (55.776922, 37.507502, 0.0)),
#  'Москва, метро Медведково': Location(метро Медведково, Калужско-Рижская линия, Москва, Россия, (55.887473, 37.661536, 0.0)),
#  'Москва, метро Проспект Вернадского': Location(метро Проспект Вернадского, Большая кольцевая линия, Москва, Россия, (55.678519, 37.503747, 0.0)),
#  'Москва, метро ВДНХ': Location(метро ВДНХ, Калужско-Рижская линия, Москва, Россия, (55.821097, 37.641045, 0.0)),
#  'Москва, метро Марьино': Location(метро Марьино, Люблинско-Дмитровская линия, Москва, Россия, (55.650028, 37.743471, 0.0)),
#  'Москва, метро Профсоюзная': Location(метро Профсоюзная, Калужско-Рижская линия, Москва, Россия, (55.67793, 37.562874, 0.0)),
#  'Москва, метро Братиславская': Location(метро Братиславская, Люблинско-Дмитровская линия, Москва, Россия, (55.659647, 37.750739, 0.0)),
#  'Москва, метро Лефортово': Location(метро Лефортово, Большая кольцевая линия, Москва, Россия, (55.764698, 37.706757, 0.0)),
#  'Москва, метро Курьяново': Location(станция Курьяново, МЦД-2 Курско-Рижский диаметр, Россия, (55.649855, 37.701439, 0.0)),
#  'Москва, метро Вешняки': Location(станция Вешняки, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.722467, 37.798107, 0.0)),
#  'Москва, метро Терехово ': Location(метро Терехово, Большая кольцевая линия, Москва, Россия, (55.748108, 37.459738, 0.0)),
#  'Москва, метро Рабочий посёлок': Location(станция Рабочий Посёлок, МЦД-1 Белорусско-Савёловский диаметр, Россия, (55.726918, 37.417886, 0.0)),
#  'Москва, метро Сортировочная': Location(станция Сортировочная, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.763108, 37.720708, 0.0)),
#  'Москва, метро Москва-Товарная': Location(станция Москва-Товарная, МЦД-2 Курско-Рижский диаметр, Россия, (55.745656, 37.688315, 0.0)),
#  'Москва, метро Серп и Молот': Location(проезд Завода Серп и Молот, Москва, Россия, (55.753509, 37.700729, 0.0)),
#  'Москва, метро Бескудниково': Location(станция Бескудниково, МЦД-1 Белорусско-Савёловский диаметр, Россия, (55.882187, 37.567698, 0.0)),
#  'Москва, метро Бабушкинская': Location(метро Бабушкинская, Калужско-Рижская линия, Москва, Россия, (55.86947, 37.664204, 0.0)),
#  'Москва, метро Улица Академика Королёва': Location(монорельс Улица Академика Королёва, Московская монорельсовая транспортная система, Москва, Россия, (55.821841, 37.626933, 0.0)),
#  'Москва, метро Улица Сергея Эйзенштейна': Location(монорельс Улица Сергея Эйзенштейна, Московская монорельсовая транспортная система, Москва, Россия, (55.82931, 37.644998, 0.0)),
#  'Москва, метро Грачёвская': Location(станция Грачёвская, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.870162, 37.508598, 0.0)),
#  'Москва, метро Беляево': Location(метро Беляево, Калужско-Рижская линия, Москва, Россия, (55.642748, 37.525836, 0.0)),
#  'Москва, метро Спартак': Location(метро Спартак, Таганско-Краснопресненская линия, Москва, Россия, (55.818103, 37.43525, 0.0)),
#  'Москва, метро Перерва': Location(станция Перерва, МЦД-2 Курско-Рижский диаметр, Россия, (55.661415, 37.716998, 0.0)),
#  'Москва, метро Панфиловская': Location(станция Панфиловская, Московское центральное кольцо, Москва, Россия, (55.798019, 37.49983, 0.0)),
#  'Москва, метро Аэропорт': Location(метро Аэропорт, Замоскворецкая линия, Москва, Россия, (55.800362, 37.53305, 0.0)),
#  'Москва, метро Мичуринский проспект': Location(метро Мичуринский проспект, Большая кольцевая линия, Москва, Россия, (55.688203, 37.485304, 0.0)),
#  'Москва, метро Трикотажная': Location(станция Трикотажная, МЦД-2 Курско-Рижский диаметр, Россия, (55.833137, 37.398976, 0.0)),
#  'Москва, метро Коммунарка': Location(метро Коммунарка, Сокольническая линия, Москва, Россия, (55.560071, 37.46865, 0.0)),
#  'Москва, метро Свиблово': Location(метро Свиблово, Калужско-Рижская линия, Москва, Россия, (55.855179, 37.652625, 0.0)),
#  'Москва, метро Ховрино': Location(метро Ховрино, Замоскворецкая линия, Москва, Россия, (55.878273, 37.480777, 0.0)),
#  'Москва, метро Новохохловская': Location(станция Новохохловская, Московское центральное кольцо, Москва, Россия, (55.724084, 37.716746, 0.0)),
#  'Москва, метро Сокол': Location(метро Сокол, Замоскворецкая линия, Москва, Россия, (55.805047, 37.514796, 0.0)),
#  'Москва, метро Зорге': Location(станция Зорге, Московское центральное кольцо, Москва, Россия, (55.789158, 37.504223, 0.0)),
#  'Москва, метро Хорошёво': Location(станция Хорошёво, Московское центральное кольцо, Москва, Россия, (55.776922, 37.507502, 0.0)),
#  'Москва, метро Октябрьское поле': Location(метро Октябрьское Поле, Таганско-Краснопресненская линия, Москва, Россия, (55.793586, 37.493326, 0.0)),
#  'Москва, метро Калужская': Location(метро Калужская, Калужско-Рижская линия, Москва, Россия, (55.656682, 37.540075, 0.0)),
#  'Москва, метро Щукинская': Location(метро Щукинская, Таганско-Краснопресненская линия, Москва, Россия, (55.808832, 37.463772, 0.0)),
#  'Москва, метро Народное Ополчение': Location(метро Народное Ополчение, Большая кольцевая линия, Москва, Россия, (55.775702, 37.48508, 0.0)),
#  'Москва, метро Кусково': Location(станция Кусково, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.739539, 37.794612, 0.0)),
#  'Москва, метро Ростокино': Location(станция Ростокино, Московское центральное кольцо, Москва, Россия, (55.839224, 37.668408, 0.0)),
#  'Москва, метро Технопарк': Location(метро Технопарк, Замоскворецкая линия, Москва, Россия, (55.693931, 37.664428, 0.0)),
#  'Москва, метро Нижегородская': Location(метро Нижегородская, Большая кольцевая линия, Москва, Россия, (55.731835, 37.729404, 0.0)),
#  'Москва, метро Новые Черёмушки': Location(метро Новые Черёмушки, Калужско-Рижская линия, Москва, Россия, (55.670077, 37.554493, 0.0)),
#  'Москва, метро Волоколамская': Location(метро Волоколамская, Арбатско-Покровская линия, Москва, Россия, (55.835508, 37.382043, 0.0)),
#  'Москва, метро Алма-Атинская': Location(метро Алма-Атинская, Замоскворецкая линия, Москва, Россия, (55.632825, 37.765911, 0.0)),
#  'Москва, метро Кленовый бульвар': Location(метро Кленовый бульвар, Большая кольцевая линия, Москва, Россия, (55.674722, 37.681595, 0.0)),
#  'Москва, метро Белокаменная': Location(станция Белокаменная, Московское центральное кольцо, Москва, Россия, (55.82938, 37.702319, 0.0)),
#  'Москва, метро Шоссе Энтузиастов': Location(метро Шоссе Энтузиастов, Калининская линия, Москва, Россия, (55.757648, 37.750909, 0.0)),
#  'Москва, метро Воронцовская': Location(метро Воронцовская, Большая кольцевая линия, Москва, Россия, (55.658845, 37.539446, 0.0)),
#  'Москва, метро Стахановская': Location(метро Стахановская, Некрасовская линия, Москва, Россия, (55.727207, 37.752257, 0.0)),
#  'Москва, метро ЗИЛ': Location(станция ЗИЛ, Московское центральное кольцо, Москва, Россия, (55.698624, 37.649049, 0.0)),
#  'Москва, метро Саларьево': Location(метро Саларьево, Сокольническая линия, Москва, Россия, (55.621816, 37.424057, 0.0)),
#  'Москва, метро Ольховая': Location(метро Ольховая, Сокольническая линия, Москва, Россия, (55.56898, 37.459056, 0.0)),
#  'Москва, метро Лихоборы': Location(метро Верхние Лихоборы, Люблинско-Дмитровская линия, Москва, Россия, (55.856235, 37.561041, 0.0)),
#  'Москва, метро Новокосино': Location(метро Новокосино, Калининская линия, Москва, Россия, (55.745113, 37.864061, 0.0)),
#  'Москва, метро Минская': Location(метро Минская, Солнцевская линия, Москва, Россия, (55.724074, 37.497414, 0.0)),
#  'Москва, метро Озёрная': Location(метро Озёрная, Солнцевская линия, Москва, Россия, (55.67058, 37.449012, 0.0)),
#  'Москва, метро Зеленоград — Крюково': Location(район Крюково, Зеленоградский административный округ, Москва, Россия, (55.96933, 37.176131, 0.0)),
#  'Москва, метро Щербинка': Location(станция Щербинка, МЦД-2 Курско-Рижский диаметр, Россия, (55.51016, 37.5622, 0.0)),
#  'Москва, метро Говорово': Location(метро Говорово, Солнцевская линия, Москва, Россия, (55.659551, 37.417266, 0.0)),
#  'Москва, метро Яхромская': Location(метро Яхромская, Люблинско-Дмитровская линия, Москва, Россия, (55.879904, 37.545429, 0.0)),
#  'Москва, метро Боровское шоссе': Location(метро Боровское шоссе, Солнцевская линия, Москва, Россия, (55.647671, 37.370131, 0.0)),
#  'Москва, метро Некрасовка': Location(метро Некрасовка, Некрасовская линия, Москва, Россия, (55.702967, 37.928039, 0.0)),
#  'Москва, метро Прокшино': Location(метро Прокшино, Сокольническая линия, Москва, Россия, (55.586456, 37.43322, 0.0)),
#  'Москва, метро Селигерская': Location(метро Селигерская, Люблинско-Дмитровская линия, Москва, Россия, (55.866561, 37.547126, 0.0)),
#  'Москва, метро Пятницкое шоссе': Location(метро Пятницкое шоссе, Арбатско-Покровская линия, Москва, Россия, (55.855967, 37.354141, 0.0)),
#  'Москва, метро Матвеевская': Location(станция Матвеевская, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.70458, 37.481693, 0.0)),
#  'Москва, метро Митино': Location(метро Митино, Арбатско-Покровская линия, Москва, Россия, (55.845734, 37.362163, 0.0)),
#  'Москва, метро Румянцево': Location(метро Румянцево, Сокольническая линия, Москва, Россия, (55.633028, 37.441404, 0.0)),
#  'Москва, метро Новопеределкино': Location(метро Новопеределкино, Солнцевская линия, Москва, Россия, (55.639613, 37.355228, 0.0)),
#  'Москва, метро Филатов Луг': Location(метро Филатов Луг, Сокольническая линия, Москва, Россия, (55.601182, 37.407995, 0.0)),
#  'Москва, метро Сетунь': Location(станция Сетунь, МЦД-1 Белорусско-Савёловский диаметр, Россия, (55.723587, 37.396722, 0.0)),
#  'Москва, метро Кокошкино': Location(станция Кокошкино, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.599057, 37.169951, 0.0)),
#  'Москва, метро Солнцево': Location(метро Солнцево, Солнцевская линия, Москва, Россия, (55.649388, 37.3909, 0.0)),
#  'Москва, метро Аминьевская': Location(метро Аминьевская, Большая кольцевая линия, Москва, Россия, (55.697189, 37.464931, 0.0)),
#  'Москва, метро Пенягино': Location(станция Пенягино, МЦД-2 Курско-Рижский диаметр, Россия, (55.822539, 37.361058, 0.0)),
#  'Москва, метро Физтех': Location(метро Физтех, Люблинско-Дмитровская линия, Москва, Россия, (55.921536, 37.546498, 0.0)),
#  'Москва, метро Пыхтино': Location(метро Пыхтино, Солнцевская линия, Москва, Россия, (55.624642, 37.296146, 0.0)),
#  'Москва, метро Люберцы': Location(станция Люберцы, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.682123, 37.897209, 0.0)),
#  'Москва, метро Аэропорт Внуково': Location(метро Аэропорт Внуково, Солнцевская линия, Москва, Россия, (55.607087, 37.287702, 0.0)),
#  'Москва, метро Моссельмаш': Location(станция Моссельмаш, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.862156, 37.527399, 0.0)),
#  'Москва, метро Улица Дмитриевского': Location(метро Улица Дмитриевского, Некрасовская линия, Москва, Россия, (55.710311, 37.879054, 0.0)),
#  'Москва, метро Силикатная': Location(станция Силикатная, МЦД-2 Курско-Рижский диаметр, Россия, (55.470459, 37.555454, 0.0)),
#  'Москва, метро Новоподрезково': Location(станция Новоподрезково, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.936534, 37.352246, 0.0)),
#  'Москва, метро Лермонтовский проспект': Location(метро Лермонтовский проспект, Таганско-Краснопресненская линия, Москва, Россия, (55.701704, 37.852383, 0.0)),
#  'Москва, метро Строгино': Location(метро Строгино, Арбатско-Покровская линия, Москва, Россия, (55.803697, 37.403118, 0.0)),
#  'Москва, метро Мнёвники': Location(метро Мнёвники, Большая кольцевая линия, Москва, Россия, (55.761153, 37.47139, 0.0)),
#  'Москва, метро Косино': Location(метро Косино, Некрасовская линия, Москва, Россия, (55.703429, 37.851314, 0.0)),
#  'Москва, метро Очаково': Location(станция Очаково, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.683148, 37.450558, 0.0)),
#  'Москва, метро Санино': Location(станция Санино, МЦД-4 Калужско-Нижегородский диаметр, Россия, (55.583886, 37.138168, 0.0)),
#  'Москва, метро Молжаниново': Location(станция Молжаниново, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.924199, 37.381351, 0.0)),
#  'Москва, метро Жулебино': Location(метро Жулебино, Таганско-Краснопресненская линия, Москва, Россия, (55.685137, 37.855797, 0.0)),
#  'Москва, метро Рассказовка': Location(метро Рассказовка, Солнцевская линия, Москва, Россия, (55.633968, 37.334756, 0.0)),
#  'Москва, метро Лухмановская': Location(метро Лухмановская, Некрасовская линия, Москва, Россия, (55.708516, 37.900578, 0.0)),
#  'Москва, метро Марк': Location(станция Марк, МЦД-1 Белорусско-Савёловский диаметр, Россия, (55.904443, 37.538269, 0.0)),
#  'Москва, метро Плющево': Location(станция Плющево, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.730497, 37.774742, 0.0)),
#  'Москва, метро Новодачная': Location(станция Новодачная, МЦД-1 Белорусско-Савёловский диаметр, Россия, (55.924396, 37.527947, 0.0)),
#  'Москва, метро Павшино': Location(станция Павшино, МЦД-2 Курско-Рижский диаметр, Россия, (55.815175, 37.341448, 0.0)),
#  'Москва, метро Ухтомская': Location(станция Ухтомская, МЦД-3 Ленинградско-Казанский диаметр, Россия, (55.698579, 37.864447, 0.0))}

# %%
df['metro'] = df['Город и метро'].map(metro)

# %%
df['metro'].isna().sum()
# Out:
# 0

# %%
df['координаты метро'] = df['metro'].apply(  # Создадим новую колонку с координатами метро.
    lambda x: tuple(x.point) if x else None)

# %%
# Создадим новую колонку с широтой метро.
df['широта метро'] = df['координаты метро'].apply(lambda x: x[0])

# %%
# Создадим новую колонку с долготой метро.
df['долгота метро'] = df['координаты метро'].apply(lambda x: x[1])

# %% [markdown]
# ## Поиск координат дома.

# %%
address = dict()
for i in range(0, df['Адрес'].nunique()):
    adr = df['Адрес'].unique()[i]
    address[adr] = geocode(adr, timeout=1)

# %%
df['address'] = df['Адрес'].map(address)  # Создадим колонку с локацией дома.

# %%
df['координаты дома'] = df['address'].apply(  # Создадим колонку с координатами дома.
    lambda x: tuple(x.point) if x else None)

# %%
# Создадим колонку с широтой дома.
df['широта дома'] = df['координаты дома'].apply(lambda x: x[0])

# %%
# Создадим колонку с долготой дома.
df['долгота дома'] = df['координаты дома'].apply(lambda x: x[1])

# %%
lon_center = 37.621031  # Долгота центра города

# %%
lat_center = 55.753595  # Широта центра города

# %% [markdown]
# ## Поиск расстояний до центра и метро.

# %%
df['Расстояние до центра'] = df[['широта дома', 'долгота дома']].apply(
    lambda x: distance.distance((x[0], x[1]), (lat_center, lon_center)).km, axis=1)

# %%
df['Расстояние до метро'] = df[['широта дома', 'долгота дома', 'широта метро', 'долгота метро']].apply(
    lambda x: distance.distance((x[0], x[1]), (x[2], x[3])).km, axis=1)

# %% [markdown]
# # Заполнение пропусков в признаке "время до метро"

# %%
man_speed = 0.083  # Средняя скорость ходьбы человека в км/мин

# %%
"""Заполним пропуски в признаке 'Время до метро'"""
for idx, name in df[df['Время до метро'].isna()].iterrows():
    speed = (df['Расстояние до метро'][idx] / man_speed).astype(int)
    df['Время до метро'][idx] = speed

# %%
df['Время до метро'].isna().sum()
# Out:
# 0

# %%
df['Время до метро'] = df['Время до метро'].astype(int)

# %% [markdown]
# # Добавление признака "Округ"

# %%
districts = ["ЦАО", "ЮАО", 'ЮЗАО', 'ЮВАО', 'ЗАО', 'СВАО', 'ВАО', 'САО',
             'СЗАО', 'НАО (Новомосковский)', 'ЗелАО']  # Список всех округов Москвы.

# %%
df['Адрес'].str. split(', ', expand=True)[1]
# Out:
# 0                         ЦАО
# 1                         ЦАО
# 2                         ЦАО
# 3                         ЦАО
# 4                         ЦАО
#                  ...
# 10762    Новоалексеевская ул.
# 10763                    СЗАО
# 10764                    ЮЗАО
# 10765                     ЮАО
# 10766                     ЮАО
# Name: 1, Length: 10767, dtype: object

# %%
df['district'] = df['Адрес'].str. split(', ', expand=True)[1]

# %%
df['district'].value_counts()
# Out:
# district
# ЦАО                      2729
# ЮАО                      1444
# ЮЗАО                     1183
# ЮВАО                     1027
# ЗАО                       944
#                          ...
# Щербаковская ул.            1
# Ордынский туп.              1
# ул. 4-я Марьиной рощи       1
# Амурская ул.                1
# Новоалексеевская ул.        1
# Name: count, Length: 115, dtype: int64

# %%
district = dict()
for i in range(0, len(df['Метро'])):
    if i not in district.keys():
        if df['district'][i] in districts:
            district[df['Метро'][i]] = df['district'][i]

# %%
df['Округ'] = df['Метро'].map(district)

# %%
"""Заменим все значения где не указан округ на 'Неизвестно' """

for ind, dis in enumerate(df['Округ']):
    if dis not in districts:
        df['Округ'][ind] = 'Неизвестно'
# Out:
# C:\Users\ser34\AppData\Local\Temp\ipykernel_5636\657050907.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Округ'][ind] = 'Неизвестно'
# C:\Users\ser34\AppData\Local\Temp\ipykernel_5636\657050907.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Округ'][ind] = 'Неизвестно'
# C:\Users\ser34\AppData\Local\Temp\ipykernel_5636\657050907.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Округ'][ind] = 'Неизвестно'
# C:\Users\ser34\AppData\Local\Temp\ipykernel_5636\657050907.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Округ'][ind] = 'Неизвестно'
# C:\Users\ser34\AppData\Local\Temp\ipykernel_5636\657050907.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Округ'][ind] = 'Неизвестно'
# C:\Users\ser34\AppData\Local\Temp\ipykernel_5636\657050907.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Округ'][ind] = 'Неизвестно'

# %% [markdown]
# Уберем уточнение "Новомосковский".

# %%
df['Округ'] = df['Округ'].str.split(' ', expand=True)[0]

# %%
df['Округ'].value_counts()
# Out:
# Округ
# ЦАО           2707
# ЮАО           1410
# ЮЗАО          1401
# ЮВАО          1081
# ЗАО            962
# СВАО           953
# ВАО            826
# САО            772
# СЗАО           515
# НАО            129
# Неизвестно       6
# ЗелАО            5
# Name: count, dtype: int64

# %% [markdown]
# # Удаление лишних колонок

# %%
df_clean = df.drop(['metro', 'address', 'Город и метро',
                    'координаты метро', 'координаты дома', 'district'], axis=1)

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10767 entries, 0 to 10766
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Название              10767 non-null  object
#  1   Адрес                 10767 non-null  object
#  2   Метро                 10767 non-null  object
#  3   Время до метро        10767 non-null  int32
#  4   Цена                  10767 non-null  float64
#  5   Цена за квадрат       10767 non-null  float64
#  6   Общая площадь         10767 non-null  float64
#  7   Жилая площадь         10767 non-null  float64
#  8   Площадь кухни         10767 non-null  float64
#  9   Этаж                  10767 non-null  int64
#  10  Год постройки         10767 non-null  int64
#  11  Тип жилья             10767 non-null  object
#  12  Высота потолков       10767 non-null  float64
#  13  Санузел               10767 non-null  int64
#  14  Вид из окон           10767 non-null  object
#  15  Ремонт                10767 non-null  object
#  16  Мусоропровод          10767 non-null  object
#  17  Количество лифтов     10767 non-null  int64
#  18  Тип дома              10767 non-null  object
#  19  Тип перекрытий        10767 non-null  object
#  20  Парковка              10767 non-null  object
#  21  Отопление             10767 non-null  object
#  22  Балкон/лоджия         10767 non-null  int64
#  23  Отделка               10767 non-null  object
#  24  Этажность здания      10767 non-null  int64
#  25  Кол-во комнат         10767 non-null  int64
#  26  широта метро          10767 non-null  float64
#  27  долгота метро         10767 non-null  float64
#  28  широта дома           10767 non-null  float64
#  29  долгота дома          10767 non-null  float64
#  30  Расстояние до центра  10767 non-null  float64
#  31  Расстояние до метро   10767 non-null  float64
#  32  Округ                 10767 non-null  object
# dtypes: float64(12), int32(1), int64(7), object(13)
# memory usage: 2.7+ MB

# %%
df_clean.to_csv("data\cian_full.csv", index=False)
